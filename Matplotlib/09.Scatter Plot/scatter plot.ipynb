# %%
import pandas as pd
from matplotlib import pyplot as plt

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y)

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y)

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y , s =100)

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y , s =100 , c = "g" , marker = "^")

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y , s =100 , c = "g" , marker = "^" ,edgecolor='black',linewidth=1 )

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y , s =100 , c = "g" , marker = "^" ,edgecolor='black' , linewidth=1, alpha=0.75)

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y , s =100 , c = "g"  ,edgecolor='black',linewidth=1 ) # lets use default marker

# %%
plt.style.use('seaborn')

colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y , s =100 , c = colors  ,edgecolor='black',linewidth=1 ) # lets use default marker

# %%
plt.style.use('seaborn')

colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y , s =100 , c = colors , cmap = "Greens"  ,edgecolor='black',linewidth=1 ) # lets use default marker # cmap (default: 'viridis')

# %%
plt.style.use('seaborn')

colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y , s =100 , c = colors , cmap = "Greens"  ,edgecolor='black',linewidth=1 ) # lets use default marker # cmap (default: 'viridis')

cbar = plt.colorbar()
cbar.set_label("Satisfaction labels")

# %%
import numpy as np

plt.style.use('seaborn')

colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

sizes = np.random.randint(80,200,len(x))

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y , s = sizes , c = colors , cmap = "Greens"  ,edgecolor='black',linewidth=1 ) # lets use default marker # cmap (default: 'viridis')

cbar = plt.colorbar()
cbar.set_label("Satisfaction labels")

# %%
import numpy as np
sizes = np.random.randint(1,100,len(x))
sizes
# Out:
# array([86, 35, 87, 55, 83, 83, 42, 98, 33, 38,  4, 51, 65, 64, 40, 43, 20,
#        25, 34, 37])

# %%
plt.style.use('seaborn')

data = pd.read_csv('data.csv')
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

plt.scatter(view_count, likes,edgecolor='black', linewidth=1, alpha=0.75)

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

plt.tight_layout()

plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

data = pd.read_csv('data.csv')
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

plt.scatter(view_count, likes,edgecolor='black', linewidth=1, alpha=0.75)

plt.xscale('log')
plt.yscale('log')

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

plt.tight_layout()

plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

data = pd.read_csv('data.csv')
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

plt.scatter(view_count, likes, c=ratio, cmap='summer', edgecolor='black', linewidth=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('Like/Dislike Ratio')

plt.xscale('log')
plt.yscale('log')

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

# dataset-1 
x1 = [89, 43, 36, 36, 95, 10,  
      66, 34, 38, 20] 
  
y1 = [21, 46, 3, 35, 67, 95,  
      53, 72, 58, 10] 
  
# dataset2 
x2 = [26, 29, 48, 64, 6, 5, 
      36, 66, 72, 40] 
  
y2 = [26, 34, 90, 33, 38,  
      20, 56, 2, 47, 15] 
  
plt.scatter(x1, y1, c ="pink",  
            linewidths = 2,  
            marker ="s",  
            edgecolor ="green",  
            s = 50) 
  
plt.scatter(x2, y2, c ="yellow", 
            linewidths = 2, 
            marker ="^",  
            edgecolor ="red",  
            s = 200) 
  
plt.xlabel("X-axis") 
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
plt.style.use('seaborn')

# dataset-1 
x1 = [89, 43, 36, 36, 95, 10,  
      66, 34, 38, 20] 
  
y1 = [21, 46, 3, 35, 67, 95,  
      53, 72, 58, 10] 
  
# dataset2 
x2 = [26, 29, 48, 64, 6, 5, 
      36, 66, 72, 40] 
  
y2 = [26, 34, 90, 33, 38,  
      20, 56, 2, 47, 15] 

plt.scatter(x1, y1, c ="pink",  
            linewidths = 2,  
            marker ="s",  
            edgecolor ="green",  
            s = 50 , vmin=6, vmax=10) 
  
plt.scatter(x2, y2, c ="yellow", 
            linewidths = 2, 
            marker ="^",  
            edgecolor ="red",  
            s = 200 , vmin=6, vmax=10) 
  
plt.xlabel("X-axis") 
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')
